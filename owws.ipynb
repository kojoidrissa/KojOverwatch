# %%
# %load owwc.py
from bs4 import BeautifulSoup
import requests
ow = requests.get('https://worldcup.playoverwatch.com/en-us/')
ow_soup = BeautifulSoup(ow.text, 'html.parser')
print(ow_soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 9]>    <html class="ie9"> <![endif]-->
# <!--[if gt IE 9]> <html> <![endif]-->
# <head>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible">
#   <meta content="width=device-width, initial-scale=1, user-scalable=no" name="viewport">
#    <meta content="World Cup 2017" property="og:title">
#     <meta content="website" property="og:type">
#      <meta content="The Overwatch World Cup is a dynamic team shooter battle between fan-selected teams from all over the globe." property="og:description">
#       <meta content="https://worldcup-static.playoverwatch.com/images/wc-2017-fb-1fa66c52294dfe9babd88c99ef5020da5c01b2a2ee95072e93a67efd58ae55cf70a9fbc6c2d7ded71d1ac7ac0a25892fa2182254f7330ac2c25359942da00457.jpg" property="og:image">
# ...

# %%
ow_soup.title
# Out:
# <title>World Cup 2017</title>

# %%
ow_soup.div['class']
# Out:
# ['Navbar', 'is-compact', 'is-auto', 'is-custom-logo']

# %%
print(ow_soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if IE 9]>    <html class="ie9"> <![endif]-->
# <!--[if gt IE 9]> <html> <![endif]-->
# <head>
#  <meta content="IE=edge" http-equiv="X-UA-Compatible">
#   <meta content="width=device-width, initial-scale=1, user-scalable=no" name="viewport">
#    <meta content="World Cup 2017" property="og:title">
#     <meta content="website" property="og:type">
#      <meta content="The Overwatch World Cup is a dynamic team shooter battle between fan-selected teams from all over the globe." property="og:description">
#       <meta content="https://worldcup-static.playoverwatch.com/images/wc-2017-fb-1fa66c52294dfe9babd88c99ef5020da5c01b2a2ee95072e93a67efd58ae55cf70a9fbc6c2d7ded71d1ac7ac0a25892fa2182254f7330ac2c25359942da00457.jpg" property="og:image">
# ...

# %%
print(ow_soup.find_all('TopCountries-row'))
# Out:
# []
